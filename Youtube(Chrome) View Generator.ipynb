# %%
from selenium import webdriver 
import requests
from itertools import cycle
import traceback
from selenium import webdriver
from bs4 import BeautifulSoup
from lxml.html import fromstring
from selenium.webdriver.support.ui import WebDriverWait 
import time 
import os
import sys

status=0
def getproxy():                           #function to get US proxies from this website 
    url="https://www.us-proxy.org/"
    page=requests.get(url)
    parser=fromstring(page.text)
    proxies=set()
    for i in parser.xpath('//tbody/tr')[:20]:
        proxy=":".join([i.xpath('.//td[1]/text()')[0],i.xpath('.//td[2]/text()')[0]])
        proxies.add(proxy)
    return proxies

proxies=getproxy()
proxypool=cycle(proxies)

link="https://www.youtube.com/watch?v=Uj5HPd5zr3c"

for x in range(11):
    proxy=next(proxypool)
    print("Requesting proxy connection ",proxy)
    try:
        driver = webdriver.Chrome('C:\chromedriver.exe')
        driver.get(link,proxy)      
    
        status=1
    except:
        print("Can't connect, Skipping")
    
    if(status==1):
        break
        
for i in range(50):
    page=requests.get(link,proxies={"http":proxy,"https":proxy})

# %%
from selenium import webdriver 
from selenium.webdriver.support.ui import WebDriverWait 
import time 
import os
import sys

for i in range(50):
    print("Iteration number: ",i)
    
    driver = webdriver.Chrome('C:\chromedriver.exe')
    driver.get("https://www.youtube.com/watch?v=4TkCGMkALp0&t=175s")      
    
time.sleep(68)

# %%
from selenium import webdriver 
from selenium.webdriver.support.ui import WebDriverWait 
import time 
import os
import sys

n=0
for i in range(650):
    print("Iteration number: ",i)
    
    driver = webdriver.Chrome('C:\chromedriver.exe')
    driver.get("https://www.youtube.com/watch?v=y63oUgzdPSI")      
    
    driver2 = webdriver.Chrome('C:\chromedriver.exe')
    driver2.get("https://www.youtube.com/watch?v=y63oUgzdPSI")
    
    driver3= webdriver.Chrome('C:\chromedriver.exe')
    driver3.get("https://www.youtube.com/watch?v=y63oUgzdPSI")  
    
    driver4= webdriver.Chrome('C:\chromedriver.exe')
    driver4.get("https://www.youtube.com/watch?v=y63oUgzdPSI")  
    
    driver5= webdriver.Chrome('C:\chromedriver.exe')
    driver5.get("https://www.youtube.com/watch?v=y63oUgzdPSI")
    
    try:
        wait = WebDriverWait(driver, 60)
#         if(driver.find_element_by_xpath("//*[@id='movie_player']/div[4]/button")):
        driver.find_element_by_xpath("//*[@id='movie_player']/div[4]/button").click()

        wait2 = WebDriverWait(driver2, 60)
#         if(driver2.find_element_by_xpath("//*[@id='movie_player']/div[4]/button")):
        driver2.find_element_by_xpath("//*[@id='movie_player']/div[4]/button").click()

        wait3 = WebDriverWait(driver3, 60)
#         if(driver3.find_element_by_xpath("//*[@id='movie_player']/div[4]/button")):
        driver2.find_element_by_xpath("//*[@id='movie_player']/div[4]/button").click()

        wait4 = WebDriverWait(driver4, 60)
#         if(driver4.find_element_by_xpath("//*[@id='movie_player']/div[4]/button")):
        driver4.find_element_by_xpath("//*[@id='movie_player']/div[4]/button").click()

        wait5 = WebDriverWait(driver5, 60)
#         if(driver5.find_element_by_xpath("//*[@id='movie_player']/div[4]/button")):
        driver5.find_element_by_xpath("//*[@id='movie_player']/div[4]/button").click()
    except:
        print("restarting again")
        time.sleep(400)
        driver.close()
        driver2.close()
        driver3.close()
        driver4.close()
        driver5.close()
        continue
    
#     driver6 = webdriver.Chrome('C:\chromedriver.exe')
#     driver6.get("https://www.youtube.com/watch?v=Uj5HPd5zr3c")
        
#     driver7= webdriver.Chrome('C:\chromedriver.exe')
#     driver7.get("https://www.youtube.com/watch?v=Uj5HPd5zr3c")
    
#     driver8= webdriver.Chrome('C:\chromedriver.exe')
#     driver8.get("https://www.youtube.com/watch?v=Uj5HPd5zr3c")
    
#     driver9= webdriver.Chrome('C:\chromedriver.exe')
#     driver9.get("https://www.youtube.com/watch?v=Uj5HPd5zr3c")
    
#     driver10= webdriver.Chrome('C:\chromedriver.exe')
#     driver10.get("https://www.youtube.com/watch?v=Uj5HPd5zr3c")      
    
    n=n+5
    print("Views increased: ",n)
    
    time.sleep(420)
    
    driver.close()
    driver2.close()
    driver3.close()
    driver4.close()
    driver5.close()
#     driver6.close()
#     driver7.close()
#     driver8.close()
#     driver9.close()
#     driver10.close()

# %%
time.sleep(5)
    
    

        wait6 = WebDriverWait(driver6, 60)
        if(driver6.find_element_by_xpath("//*[@id='movie_player']/div[4]/button")):
            driver6.find_element_by_xpath("//*[@id='movie_player']/div[4]/button").click()

        wait7 = WebDriverWait(driver7, 60)
        if(driver7.find_element_by_xpath("//*[@id='movie_player']/div[4]/button")):
            driver7.find_element_by_xpath("//*[@id='movie_player']/div[4]/button").click()

        wait8 = WebDriverWait(driver8, 60)
        if(driver8.find_element_by_xpath("//*[@id='movie_player']/div[4]/button")):
            driver8.find_element_by_xpath("//*[@id='movie_player']/div[4]/button").click()

        wait9 = WebDriverWait(driver9, 60)
        if(driver9.find_element_by_xpath("//*[@id='movie_player']/div[4]/button")):
            driver9.find_element_by_xpath("//*[@id='movie_player']/div[4]/button").click()

        wait10 = WebDriverWait(driver10, 60)
        if(driver10.find_element_by_xpath("//*[@id='movie_player']/div[4]/button")):
            driver10.find_element_by_xpath("//*[@id='movie_player']/div[4]/button").click()
        
    
        
        continue

# %%
try:
        wait = WebDriverWait(driver, 60)
        if(driver.find_element_by_xpath("//*[@id='movie_player']/div[4]/button")):
            driver.find_element_by_xpath("//*[@id='movie_player']/div[4]/button").click()

        wait2 = WebDriverWait(driver2, 60)
        if(driver2.find_element_by_xpath("//*[@id='movie_player']/div[4]/button")):
            driver2.find_element_by_xpath("//*[@id='movie_player']/div[4]/button").click()

        wait3 = WebDriverWait(driver3, 60)
        if(driver3.find_element_by_xpath("//*[@id='movie_player']/div[4]/button")):
            driver2.find_element_by_xpath("//*[@id='movie_player']/div[4]/button").click()

        wait4 = WebDriverWait(driver4, 60)
        if(driver4.find_element_by_xpath("//*[@id='movie_player']/div[4]/button")):
            driver4.find_element_by_xpath("//*[@id='movie_player']/div[4]/button").click()

        wait5 = WebDriverWait(driver5, 60)
        if(driver5.find_element_by_xpath("//*[@id='movie_player']/div[4]/button")):
            driver5.find_element_by_xpath("//*[@id='movie_player']/div[4]/button").click()
    except:
        print("restarting again")
        time.sleep(60)
        driver.close()
        driver2.close()
        driver3.close()
        driver4.close()
        driver5.close()
        driver6.close()
        driver7.close()
        driver8.close()
        driver9.close()
        driver10.close()

# %%
try:        
    import wget
    import requests
    from bs4 import BeautifulSoup
    import csv
    import platform
    from selenium import webdriver
    from selenium.common.exceptions import NoSuchElementException
    from ip2geotools.databases.noncommercial import DbIpCity
    from random import choice
    import pandas as pd
    import sys
except:
    print("Error: Required Libraries not found.")
    sys.exit()
    
n=0

for i in range (300):

    def first_level_crawling():
        try:
            proxypage=requests.get("https://www.sslproxies.org/")
            soup2=BeautifulSoup(proxypage.content,"html.parser")
        except:
            pass

        
        try:
            proxy={choice(list(map(lambda x:x[0]+x[1],list(zip(map(lambda x:x.text, soup2.findAll('td')[::8]),
                                                                              map(lambda x:x.text, soup2.findAll('td')[1::8]))))))}
            print("Using Proxy: ",proxy)
                
        except:
            pass
       
        return proxy

    try:
        PROXY=first_level_crawling()

        chrome_options = WebDriverWait.ChromeOptions()
        chrome_options.add_argument('--proxy-server=%s' % PROXY)

        chrome = webdriver.Chrome(chrome_options=chrome_options)
        chrome.get("https://www.youtube.com/watch?v=4TkCGMkALp0&t=175s")

        url = "https://www.youtube.com/watch?v=4TkCGMkALp0&t=175s"

        driver = webdriver.Chrome('C:\chromedriver.exe')    
        driver.get(url)
        driver2 = webdriver.Chrome('C:\chromedriver.exe')
        driver2.get(url)    
        driver3= webdriver.Chrome('C:\chromedriver.exe')
        driver3.get(url)      
        driver4= webdriver.Chrome('C:\chromedriver.exe')
        driver4.get(url)      
        driver5= webdriver.Chrome('C:\chromedriver.exe')
        driver5.get(url)

    
        wait = WebDriverWait(driver, 60)
        driver.find_element_by_xpath("//*[@id='movie_player']/div[4]/button").click()
        
        wait2 = WebDriverWait(driver2, 60)
        driver2.find_element_by_xpath("//*[@id='movie_player']/div[4]/button").click()

        wait3 = WebDriverWait(driver3, 60)
        driver2.find_element_by_xpath("//*[@id='movie_player']/div[4]/button").click()

        wait4 = WebDriverWait(driver4, 60)
        driver4.find_element_by_xpath("//*[@id='movie_player']/div[4]/button").click()

        wait5 = WebDriverWait(driver5, 60)
        driver5.find_element_by_xpath("//*[@id='movie_player']/div[4]/button").click()
        
    except:
        print("restarting again")
        time.sleep(150)
        driver.close()
        driver2.close()
        driver3.close()
        driver4.close()
        driver5.close()
        continue
        
    n=n+5
    print("Views increased: ",n)
    
    time.sleep(150)
    
    driver.close()
    driver2.close()
    driver3.close()
    driver4.close()
    driver5.close()
